# %%
from AutoSys2D import FitzHugh_Nagumo


FHN_std_parameters = {'a': 0.7, 
                  'b': 0.8,
                  'tau': 12.5,
                  'r': 0.1,
                  'i_ext': 3.2418,
}
FHN_cell = FitzHugh_Nagumo(x0=-1.5, y0=-1., parameters=FHN_std_parameters, run_time=500, front_end=True)
FHN_cell.run()
# Out:
# /home/work/.conda/envs/py39env/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# %matplotlib notebook
FHN_cell.animation()
# Out:
# <img src="data:image/png;base64,..." width="1050">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 FHN_cell.animation()
#
# File ~/LMUnextCloud/Projects/ComputationalBiology/Part 1/AutoSys2D.py:199, in AutonomousSystem2D.animation(self)
#     197 self.ax1.legend(fontsize=6)
#     198 for i in range(5,len(self.t),5):
# --> 199     self.update(i)
#
# File ~/LMUnextCloud/Projects/ComputationalBiology/Part 1/AutoSys2D.py:153, in AutonomousSystem2D.update(self, n)
#     151     dot.set_xdata(self.x[n-2:n])
#     152     dot.set_ydata(self.y[n-2:n])
# --> 153 self.fig.canvas.draw()
#     154 #self.canvas = FigureCanvasAgg(self.fig)
#     155 time.sleep(0.03)
#
# ...

# %%
FHN_cell.webapp_animation()
# Out:
# '<video width="1050" height="524" controls autoplay loop>\n  <source type="video/mp4" src="...\\ncXBtaW49MCBxcG1heD02OSBxcHN0ZXA9NCBpcF9yYXRp
# ...
