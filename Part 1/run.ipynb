# %%
from AutoSys2D import FitzHugh_Nagumo


FHN_std_parameters = {'a': 0.7, 
                  'b': 0.8,
                  'tau': 12.5,
                  'r': 0.1,
                  'i_ext': 3.2418,
}
FHN_cell = FitzHugh_Nagumo(x0=-1.5, y0=-1., parameters=FHN_std_parameters, run_time=500, front_end=True)
FHN_cell.run()
# Out:
# /home/work/.conda/envs/py39env/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Show animation of solution

# %%
# %matplotlib notebook
FHN_cell.notebook_animation()
# Out:
# <div id='62c84fc3-d08f-4763-b892-9ee32e4d5f6e'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/PIL/ImageFile.py:504, in _save(im, fp, tile, bufsize)
#     503 try:
# --> 504     fh = fp.fileno()
#     505     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 FHN_cell.notebook_animation()
#
# File ~/LMUnextCloud/Projects/ComputationalBiology/ComputationalBiology/Part 1/AutoSys2D.py:244, in AutonomousSystem2D.notebook_animation(self)
#     242 self.ax1.legend(fontsize=6)
#     243 for i in range(5,len(self.t),5):
# --> 244     self.update(i)
#
# File ~/LMUnextCloud/Projects/ComputationalBiology/ComputationalBiology/Part 1/AutoSys2D.py:154, in AutonomousSystem2D.update(self, n)
#     152     dot.set_xdata(self.x[n-2:n])
#     153     dot.set_ydata(self.y[n-2:n])
# --> 154 self.fig.canvas.draw()
#     155 #self.canvas = FigureCanvasAgg(self.fig)
#     156 time.sleep(0.03)
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:190, in FigureCanvasWebAggCore.draw(self)
#     188     super().draw()
#     189 finally:
# --> 190     self.manager.refresh_all()
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:496, in FigureManagerWebAgg.refresh_all(self)
#     494 def refresh_all(self):
#     495     if self.web_sockets:
# --> 496         diff = self.canvas.get_diff_image()
#     497         if diff is not None:
#     498             for s in self.web_sockets:
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py:255, in FigureCanvasWebAggCore.get_diff_image(self)
#     253 data = output.view(dtype=np.uint8).reshape((*output.shape, 4))
#     254 with BytesIO() as png:
# --> 255     Image.fromarray(data).save(png, format="png")
#     256     return png.getvalue()
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/PIL/Image.py:2240, in Image.save(self, fp, format, **params)
#    2237         fp = builtins.open(filename, "w+b")
#    2239 try:
# -> 2240     save_handler(self, fp, filename)
#    2241 finally:
#    2242     # do what we can to clean up
#    2243     if open_fp:
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/PIL/PngImagePlugin.py:1348, in _save(im, fp, filename, chunk, save_all)
#    1346     _write_multiple_frames(im, fp, chunk, rawmode)
#    1347 else:
# -> 1348     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1350 if info:
#    1351     for info_chunk in info.chunks:
#
# File ~/.conda/envs/py39env/lib/python3.9/site-packages/PIL/ImageFile.py:518, in _save(im, fp, tile, bufsize)
#     516 else:
#     517     while True:
# --> 518         l, s, d = e.encode(bufsize)
#     519         fp.write(d)
#     520         if s:
#
# KeyboardInterrupt:

# %% [markdown]
# # Create video

# %%
# crate video
# this may take a while...
video = FHN_cell.webapp_animation()
vid = video.to_html5_video()
# Out:
# <div id='f22f3a77-3c35-4578-97b1-8a54ed887747'></div>

# %%
# display video in notebook
from IPython import display 
# embedding for the video 
html = display.HTML(vid) 
  # draw the animation 
display.display(html)
# Out:
# <video width="1050" height="524" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# save video to disk
# may also take a while...
import matplotlib.animation as animation 
writervideo = animation.FFMpegWriter(fps=60) 
video.save('FHN.mp4', writer=writervideo)
# Out:
# <div id='3d11a1c0-3ab7-4182-b9e6-c7f344cd5168'></div>
